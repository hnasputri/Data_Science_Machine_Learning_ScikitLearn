# %% [markdown]
# 15 Classification Task dengan Decision Tree

# %% [markdown]
# 2273010 - Hana Saputri

# %% [markdown]
# Source: Youtube Indonesia Belajar

# %% [markdown]
# Referensi: https://en.wikipedia.org/wiki/Decision_tree_learning

# %% [markdown]
# Konsep Dasar

# %% [markdown]
# Terminology: root node, internal node, leaf node

# %% [markdown]
# ![decision_tree_example.png](attachment:b0385bf7-ff5c-4ed9-bbb8-06b51b4e6c1d.png)

# %% [markdown]
# Gini Impurity

# %% [markdown]
# ![gini_example.png](attachment:ca0a679c-6626-45f9-83fc-9f6c1ced1024.png)

# %% [markdown]
# Ruas Kiri:
# G = 1 - \sum_i^n P_i^2
#   = 1 - P(biru)^2
#   = 1 - (\frac{4}{4})^2 = 0

# %% [markdown]
# Ruas Kanan:
# G = 1 - \sum_i^n P_i^2
#   = 1 - (P(biru)^2 + P(hijau)^2)
#   = 1 - ( (\frac{1}{6})^2 + (\frac{5}{6})^2 ) = 0.278

# %% [markdown]
# Average Gini Impurity:
# G = \frac{4}{4+6} x 0 + \frac{6}{4+6} x 0.278
#   = 0.1668

# %% [markdown]
# Information Gain

# %% [markdown]
# ![information_gain.png](attachment:a814fefa-04ab-4313-bdcb-1288255d792f.png)

# %% [markdown]
# Membangun Decision Tree

# %% [markdown]
# ![build_decision_tree.png](attachment:b364fbca-738f-417c-acd0-712c9028621b.png)

# %% [markdown]
# G = 1 - (P(apple)^2 + P(grape)^2 + P(lemon)^2)
#   = 1 - ( (\frac{2}{5})^2 + (\frac{2}{5})^2 + (\frac{1}{5})^2 )
#   = 0.63

# %%
1 - ( (2/5)**2 + (2/5)**2 + (1/5)**2 )
# Out:
# 0.6399999999999999

# %%
import pandas as pd

training_data = [
    ['Green', 3, 'Apple'],
    ['Yellow', 3, 'Apple'],
    ['Red', 1, 'Grape'],
    ['Red', 1, 'Grape'],
    ['Yellow', 3, 'Lemon'],
]

# Column labels.
# These are used only to print the tree.
header = ["Color", "Diameter", "Label"]

pd.DataFrame(training_data, columns=header)
# Out:
#     Color  Diameter  Label
# 0   Green         3  Apple
# 1  Yellow         3  Apple
# 2     Red         1  Grape
# 3     Red         1  Grape
# 4  Yellow         3  Lemon

# %% [markdown]
# Dataset

# %% [markdown]
# Referensi: https://en.wikipedia.org/wiki/Iris_flower_data_set

# %%
from sklearn.datasets import load_iris

X, y = load_iris(return_X_y=True)

print(f'Dimensi Feature: {X.shape}')
print(f'Class: {set(y)}')
# Out:
# Dimensi Feature: (150, 4)
# Class: {0, 1, 2}

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.3,
                                                    random_state=0)

# %% [markdown]
# Classification dengan DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(max_depth=4)

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %% [markdown]
# Visualisasi Model

# %%
import matplotlib.pyplot as plt
from sklearn import tree

plt.rcParams['figure.dpi'] = 85
plt.subplots(figsize=(10, 10))
tree.plot_tree(model, fontsize=10)
plt.show()

# %% [markdown]
# ![download.png](attachment:eef0e1e5-7df4-452f-ad78-bc6983e18017.png)

# %% [markdown]
# Evaluasi Model

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
